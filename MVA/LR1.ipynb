# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy import stats

# %%
data = pd.read_csv('datasets\Diamonds Prices2022.csv', index_col=0)

cut_factor = pd.factorize(data['cut'])
data['cut'] = cut_factor[0]

color_factor = pd.factorize(data['color'])
data['color'] = color_factor[0]

color_factor = pd.factorize(data['clarity'])
data['clarity'] = color_factor[0]

# %%
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 1       0.23    0      0        0   61.5   55.0    326  3.95  3.98  2.43
# 2       0.21    1      0        1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23    2      0        2   56.9   65.0    327  4.05  4.07  2.31
# 4       0.29    1      1        3   62.4   58.0    334  4.20  4.23  2.63
# 5       0.31    2      2        0   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53939   0.86    1      3        0   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75    0      6        0   62.2   55.0   2757  5.83  5.87  3.64
# 53941   0.71    1      0        1   60.5   55.0   2756  5.79  5.74  3.49
# 53942   0.71    1      4        1   59.8   62.0   2756  5.74  5.73  3.43
# 53943   0.70    3      0        3   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 10 columns]

# %%
y = data.price
x = data.drop(['price'], axis='columns')

# %%
x
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 1       0.23    0      0        0   61.5   55.0  3.95  3.98  2.43
# 2       0.21    1      0        1   59.8   61.0  3.89  3.84  2.31
# 3       0.23    2      0        2   56.9   65.0  4.05  4.07  2.31
# 4       0.29    1      1        3   62.4   58.0  4.20  4.23  2.63
# 5       0.31    2      2        0   63.3   58.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 53939   0.86    1      3        0   61.0   58.0  6.15  6.12  3.74
# 53940   0.75    0      6        0   62.2   55.0  5.83  5.87  3.64
# 53941   0.71    1      0        1   60.5   55.0  5.79  5.74  3.49
# 53942   0.71    1      4        1   59.8   62.0  5.74  5.73  3.43
# 53943   0.70    3      0        3   60.5   59.0  5.71  5.76  3.47
#
# [53943 rows x 9 columns]

# %%
sns.distplot(x['carat'])
# Out:
# C:\Users\rkozl\AppData\Local\Temp\ipykernel_14044\2675984571.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x['carat'])
# <Axes: xlabel='carat', ylabel='Density'>

# %%
# Import 
import numpy as np
import matplotlib.pyplot as plt

# Generate random normally distributed data

# Histogram
heights,bins = np.histogram(x['cut'],bins=50)
plt.hist(bins,heights)

# %%
# dummies_cut = pd.get_dummies(data.cut)
# data = pd.concat([data, dummies_cut], axis='columns')

# dummies_cut = pd.get_dummies(data.color)
# data = pd.concat([data, dummies_cut], axis='columns')
 
# dummies_cut = pd.get_dummies(data.clarity)
# data = pd.concat([data, dummies_cut], axis='columns')
 
# data = data.drop(['cut', 'color', 'clarity'], axis='columns')
 
# data
# Out:
#        carat  depth  table  price     x     y     z  Fair  Good  Ideal  ...  \
# 1       0.23   61.5   55.0    326  3.95  3.98  2.43     0     0      1  ...
# 2       0.21   59.8   61.0    326  3.89  3.84  2.31     0     0      0  ...
# 3       0.23   56.9   65.0    327  4.05  4.07  2.31     0     1      0  ...
# 4       0.29   62.4   58.0    334  4.20  4.23  2.63     0     0      0  ...
# 5       0.31   63.3   58.0    335  4.34  4.35  2.75     0     1      0  ...
# ...      ...    ...    ...    ...   ...   ...   ...   ...   ...    ...  ...
# 53939   0.86   61.0   58.0   2757  6.15  6.12  3.74     0     0      0  ...
# 53940   0.75   62.2   55.0   2757  5.83  5.87  3.64     0     0      1  ...
# 53941   0.71   60.5   55.0   2756  5.79  5.74  3.49     0     0      0  ...
# 53942   0.71   59.8   62.0   2756  5.74  5.73  3.43     0     0      0  ...
# 53943   0.70   60.5   59.0   2757  5.71  5.76  3.47     0     0      0  ...
#
#        I  J  I1  IF  SI1  SI2  VS1  VS2  VVS1  VVS2
# ...
